# %%
import pickletools

file_path = 'sinhala_stt_processor.pkl'

with open(file_path, 'rb') as f:
    disassembled = pickletools.dis(f)
# Out:
#     0: \x80 PROTO      4
#     2: \x95 FRAME      1200
#    11: \x8c SHORT_BINUNICODE '__main__'
#    21: \x94 MEMOIZE    (as 0)
#    22: \x8c SHORT_BINUNICODE 'SinhalaSTTDataProcessor'
#    47: \x94 MEMOIZE    (as 1)
#    48: \x93 STACK_GLOBAL
#    49: \x94 MEMOIZE    (as 2)
#    50: )    EMPTY_TUPLE
#    51: \x81 NEWOBJ
#    52: \x94 MEMOIZE    (as 3)
#    53: }    EMPTY_DICT
#    54: \x94 MEMOIZE    (as 4)
#    55: (    MARK
#    56: \x8c     SHORT_BINUNICODE 'sample_rate'
#    69: \x94     MEMOIZE    (as 5)
#    70: M        BININT2    16000
#    73: \x8c     SHORT_BINUNICODE 'max_length'
#    85: \x94     MEMOIZE    (as 6)
#    86: J        BININT     160000
#    91: \x8c     SHORT_BINUNICODE 'char_to_idx'
#   104: \x94     MEMOIZE    (as 7)
#   105: }        EMPTY_DICT
#   106: \x94     MEMOIZE    (as 8)
#   107: (        MARK
#   108: \x8c         SHORT_BINUNICODE '<pad>'
#   115: \x94         MEMOIZE    (as 9)
#   116: K            BININT1    0
# ...
